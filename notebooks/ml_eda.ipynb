# %% [markdown]
# # ML EDA Notebook
#
# In this notebook we will explore various ML appraoches to our dataset to understand modelling, clustering, and dimension reduction ptoential

# %%
import pandas as pd
data = pd.read_csv('../data/cleaned_data_v2.csv')

# %%
data
# Out:
#         Unnamed: 0  EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  ...  \
# 0                0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0  ...
# 1                1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0  ...
# 2                2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0  ...
# 3                3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0  ...
# 4                5   3.0   3.0   4.0   2.0   4.0   2.0   2.0   3.0   3.0  ...
# ...            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 695699     1015334   4.0   1.0   4.0   2.0   4.0   3.0   3.0   2.0   3.0  ...
# 695700     1015335   5.0   1.0   5.0   2.0   4.0   2.0   3.0   1.0   5.0  ...
# 695701     1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0  ...
# 695702     1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0  ...
# 695703     1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0  ...
#
# ...
